# %%
from Anderson import Anderson
import matplotlib.pyplot as plt
from Colors import Colors, nice_grid, nice_legend

global_dpi = 300

# %%
aa: Anderson = Anderson().get_from_pkl(file='cluster_results/t17_k5.pkl')
print(aa.times)
# Out:
# [0.0, 0.5, 1.5, 3.0, 5.0, 10.0, 20.0, 30.0, 40.0, 50.0, 75.0, 100.0, 125.0, 150.0, 175.0, 200.0, 225.0, 250.0]

# %%
aa.plot_x(time=225.0, dpi=global_dpi)
aa.plot_fx(time=225.0, dpi=global_dpi)

# %%
aa.times
aa.plot_x_norm(time=150.0, dpi=global_dpi, order=2, yscale='linear')
aa.plot_fx_norm(time=150.0, dpi=global_dpi, order=2, yscale='linear')
# Out:
# L2 = [np.float64(0.03436934772182927), np.float64(0.019355076984611603), np.float64(0.005983274960840967), np.float64(0.005767786177950081), np.float64(0.0015713720462416573)]
# L2 = [np.float64(0.04581127459501287), np.float64(0.02258470608320097), np.float64(0.01995992497978282), np.float64(0.004760255876320505)]

# %%
aa.plot_all_x(dpi=global_dpi)

# %%
from aa_validator import validate_case
validate_case(time=225.0, file='cluster_results/t16_k5.pkl', k_max=5, m=4, dpi=global_dpi)
# Out:
# Computed fixed point (last x_next) =  [0.02164395 0.04913417 0.06596435 0.07447275 0.07767885 0.07817354
#  0.07768457 0.07701226 0.0761378  0.07498689 0.07358729 0.07103957
#  0.06608404 0.05688599 0.04145181 0.01806217]
# Last n_next value from vector x =  [0.02164395 0.04913417 0.06596435 0.07447275 0.07767885 0.07817354
#  0.07768457 0.07701226 0.0761378  0.07498689 0.07358729 0.07103957
#  0.06608404 0.05688599 0.04145181 0.01806217]
# Iterations: 5
# Alpha sums are == 1.0
# Alphas = [-0.07957616 -0.04770236  0.35524972  0.37693776  0.39509104]
